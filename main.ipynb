# %%
from datetime import datetime, timedelta
from pulp import LpProblem, LpVariable, lpSum, LpBinary, LpMinimize, LpStatus
import json

# Define the problem
prob = LpProblem("nurse_scheduling", LpMinimize)

# Parameters
start_date = datetime(2024, 1, 1)
num_days = 31
dates = [(start_date + timedelta(days=i)) for i in range(num_days)]
shifts = ["day", "evening", "night"]
nurse_ids = list(range(32))
max_shifts_per_month = 31
max_shifts_per_day = 2

# Define nurse rules
nurses = {}
for i in nurse_ids:
    if i < 1:  
        nurses[i] = ["CNL"]
    elif i < 6:  
        nurses[i] = ["Head", "Nurse"]
    else:  
        nurses[i] = ["Nurse"]

# Define shift demands 
demand = {
    "Saturday": {"day": {"Nurse": 6, "CNL": 1 , "Head": 0}, "evening": {"Nurse": 5, "CNL": 0, "Head": 1}, "night": {"Nurse": 5, "CNL": 0, "Head": 1}},
    "Sunday": {"day": {"Nurse": 6, "CNL": 1, "Head": 0}, "evening": {"Nurse": 5, "CNL": 0, "Head": 1}, "night": {"Nurse": 5, "CNL": 0, "Head": 1}},
    "Monday": {"day": {"Nurse": 6, "CNL": 1, "Head": 0}, "evening": {"Nurse": 5, "CNL": 0, "Head": 1}, "night": {"Nurse": 5, "CNL": 0, "Head": 1}},
    "Tuesday": {"day": {"Nurse": 6, "CNL": 1, "Head": 0}, "evening": {"Nurse": 5, "CNL": 0, "Head": 1}, "night": {"Nurse": 5, "CNL": 0, "Head": 1}},
    "Wednesday": {"day": {"Nurse": 6, "CNL": 1, "Head": 0}, "evening": {"Nurse": 5, "CNL": 0, "Head": 1}, "night": {"Nurse": 5, "CNL": 0, "Head": 1}},
    "Thursday": {"day": {"Nurse": 6, "CNL": 1, "Head": 0}, "evening": {"Nurse": 5, "CNL": 0, "Head": 1}, "night": {"Nurse": 5, "CNL": 0, "Head": 1}},
    "Friday": {"day": {"Nurse": 6, "CNL": 0, "Head": 1}, "evening": {"Nurse": 5, "CNL": 0, "Head": 1}, "night": {"Nurse": 5, "CNL": 0, "Head": 1}},
}

# Decision variables 
assignments = LpVariable.dicts(
    "Assignments",
    ((n, s, d, p) for n in nurse_ids for s in shifts for d in dates for p in nurses[n]),
    cat=LpBinary
)

demand_penalties = LpVariable.dicts(
    "demand penalties",
    ((d, s, p) for d in dates for s in shifts for p in ["Nurse", "CNL", "Head"]),
    lowBound=0, cat='Integer'
)
preferred_days = {
    1: [(dates[0], "evening"), (dates[0], "night")], 
    3: [(dates[1], "night")]   
}

off_days = {
    0: [(dates[0], "day"), (dates[1], "day")] 
}

# Objective function
penalty_weight = 1000
prob += lpSum(assignments) + penalty_weight * lpSum(demand_penalties)

# Constraints for shift demand
for d in dates:
    weekday = d.strftime("%A")
    for s in shifts:
        for p in demand[weekday][s]:
            required_count = demand[weekday][s][p]
            prob += (
                lpSum(assignments[n, s, d, p] for n in nurse_ids if p in nurses[n])
                + demand_penalties[d, s, p]
                >= required_count
            )

# Ensure at least one CNL or Head per shift
for d in dates:
    for s in shifts:
        prob += lpSum(assignments[n, s, d, "CNL"] for n in range(1)) + lpSum(assignments[n, s, d, "Head"] for n in range(1, 6)) >= 1

# Max shifts per month 
for n in nurse_ids:
    prob += lpSum(assignments[n, s, d, p] for s in shifts for d in dates for p in nurses[n]) <= max_shifts_per_month

# Max shifts per day 
for n in nurse_ids:
    for d in dates:
        prob += lpSum(assignments[n, s, d, p] for s in shifts for p in nurses[n]) <= max_shifts_per_day

# Ensure no night shift on the next day
for n in nurse_ids:
    for d in range(len(dates) - 1):
        prob += lpSum(assignments[n, 'day', dates[d + 1], p] + assignments[n, "night", dates[d], p] for p in nurses[n]) <= 1
        prob += lpSum(assignments[n, 'evening', dates[d + 1], p] + assignments[n, "night", dates[d], p] for p in nurses[n]) <= 1
        prob += lpSum(assignments[n, 'night', dates[d + 1], p] + assignments[n, "night", dates[d], p] for p in nurses[n]) <= 1

# Preferred days
for n, preferences in preferred_days.items():
        for d, s in preferences:
            prob += lpSum(assignments[n, s, d, p] for p in nurses[n]) == 1

# Off days 
for n, preferences in off_days.items():
    for d, s in preferences:
        prob += lpSum(assignments[n, s, d, p] for p in nurses[n]) == 0


# Solve the problem
prob.solve()

# Output results
def format_output_as_json(assignments, shifts, dates):
    output = []
    for d in dates:
        weekday = d.strftime("%A")
        for s in shifts:
            assigned_nurses = []
            for n in nurse_ids:
                for p in nurses[n]:
                    if assignments[n, s, d, p].varValue == 1:
                        assigned_nurses.append({"id": n, "role": p})
            if assigned_nurses:
                head_nurse = next((n for n in assigned_nurses if n["role"] == "Head"), None)
                cnl_nurse = next((n for n in assigned_nurses if n["role"] == "CNL"), None)
                output.append({
                    "date": d.strftime("%Y-%m-%d"),
                    "weekday": weekday,
                    "shift": s,
                    "nurses_assigned": assigned_nurses,
                    "head_nurse": head_nurse if head_nurse else {"id": None, "role": "None"},
                    "cnl_nurse": cnl_nurse if cnl_nurse else {"id": None, "role": "None"} if s == "day" and weekday != "Friday" else {"id": None, "role": "None"}
                })
    return json.dumps(output, indent=4)

# Generate JSON output
json_output = format_output_as_json(assignments, shifts, dates)

# Print output
print(json_output)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/miniconda3/envs/DS/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/_z/mbltc11j1kxchc3w07g4ryr40000gn/T/6dcf3c11d5e74f649ff9d069547806c0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/_z/mbltc11j1kxchc3w07g4ryr40000gn/T/6dcf3c11d5e74f649ff9d069547806c0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 4286 COLUMNS
# At line 33275 RHS
# At line 37557 BOUNDS
# At line 41278 ENDATA
# Problem MODEL has 4281 rows, 3720 columns and 17828 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 2589 - 0.01 seconds
# Cgl0002I 2 variables fixed
# Cgl0003I 0 fixed, 184 tightened bounds, 958 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 148 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 4164 rows, 3604 columns (3604 integer (3420 of which binary)) and 18492 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 2589
# Cbc0038I Cleaned solution of 2589
# Cbc0038I Before mini branch and bound, 3604 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.10 seconds)
# Cbc0038I After 0.10 seconds - Feasibility pump exiting with objective of 2589 - took 0.00 seconds
# Cbc0012I Integer solution of 2589 found by feasibility pump after 0 iterations and 0 nodes (0.10 seconds)
# Cbc0001I Search completed - best objective 2589, took 0 iterations and 0 nodes (0.10 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 2589 to 2589
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2589.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.10
# Time (Wallclock seconds):       0.12
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.12   (Wallclock seconds):       0.14
#
# [
#     {
#         "date": "2024-01-01",
#         "weekday": "Monday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 2,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 3,
#                 "role": "Head"
#             },
#             {
#                 "id": 7,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 16,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 25,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 3,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-01",
#         "weekday": "Monday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Head"
#             },
#             {
#                 "id": 5,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 8,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 1,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-01",
#         "weekday": "Monday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 2,
#                 "role": "Head"
#             },
#             {
#                 "id": 7,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 8,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 2,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-02",
#         "weekday": "Tuesday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 3,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 4,
#                 "role": "Head"
#             },
#             {
#                 "id": 5,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 10,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 30,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 4,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-02",
#         "weekday": "Tuesday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 4,
#                 "role": "Head"
#             },
#             {
#                 "id": 6,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 9,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 16,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 24,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 4,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-02",
#         "weekday": "Tuesday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 3,
#                 "role": "Head"
#             },
#             {
#                 "id": 5,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 24,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 25,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 27,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 3,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-03",
#         "weekday": "Wednesday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 17,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-03",
#         "weekday": "Wednesday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Head"
#             },
#             {
#                 "id": 2,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 12,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 17,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 22,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 1,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-03",
#         "weekday": "Wednesday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 4,
#                 "role": "Head"
#             },
#             {
#                 "id": 16,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 18,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 28,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 4,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-04",
#         "weekday": "Thursday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 1,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 6,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 9,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 12,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 30,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-04",
#         "weekday": "Thursday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Head"
#             },
#             {
#                 "id": 7,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 23,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 24,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 27,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 1,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-04",
#         "weekday": "Thursday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 3,
#                 "role": "Head"
#             },
#             {
#                 "id": 9,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 19,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 23,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 3,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-05",
#         "weekday": "Friday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 2,
#                 "role": "Head"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 12,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 28,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 30,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 2,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-05",
#         "weekday": "Friday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 2,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 4,
#                 "role": "Head"
#             },
#             {
#                 "id": 6,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 25,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 27,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 4,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-05",
#         "weekday": "Friday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 4,
#                 "role": "Head"
#             },
#             {
#                 "id": 10,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 22,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 24,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 4,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-06",
#         "weekday": "Saturday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 1,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 3,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 5,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 23,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-06",
#         "weekday": "Saturday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 2,
#                 "role": "Head"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 16,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 19,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 30,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 2,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-06",
#         "weekday": "Saturday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 2,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 5,
#                 "role": "Head"
#             },
#             {
#                 "id": 7,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 8,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 12,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 30,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 5,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-07",
#         "weekday": "Sunday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 6,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 17,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 19,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 25,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-07",
#         "weekday": "Sunday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 4,
#                 "role": "Head"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 4,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-07",
#         "weekday": "Sunday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Head"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 16,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 18,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 19,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 25,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 1,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-08",
#         "weekday": "Monday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 2,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 3,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 28,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-08",
#         "weekday": "Monday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 2,
#                 "role": "Head"
#             },
#             {
#                 "id": 5,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 10,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 12,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 2,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-08",
#         "weekday": "Monday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 5,
#                 "role": "Head"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 22,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 23,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 30,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 5,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-09",
#         "weekday": "Tuesday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 1,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 9,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 25,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-09",
#         "weekday": "Tuesday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 4,
#                 "role": "Head"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 24,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 28,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 4,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-09",
#         "weekday": "Tuesday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 2,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 4,
#                 "role": "Head"
#             },
#             {
#                 "id": 8,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 12,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 28,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 4,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-10",
#         "weekday": "Wednesday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 1,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 16,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-10",
#         "weekday": "Wednesday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 5,
#                 "role": "Head"
#             },
#             {
#                 "id": 10,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 18,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 5,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-10",
#         "weekday": "Wednesday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Head"
#             },
#             {
#                 "id": 16,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 30,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 1,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-11",
#         "weekday": "Thursday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 4,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 6,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 25,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-11",
#         "weekday": "Thursday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 5,
#                 "role": "Head"
#             },
#             {
#                 "id": 9,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 23,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 27,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 5,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-11",
#         "weekday": "Thursday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 3,
#                 "role": "Head"
#             },
#             {
#                 "id": 7,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 23,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 24,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 3,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-12",
#         "weekday": "Friday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 5,
#                 "role": "Head"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 28,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 5,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-12",
#         "weekday": "Friday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Head"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 16,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 22,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 1,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-12",
#         "weekday": "Friday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Head"
#             },
#             {
#                 "id": 5,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 25,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 27,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 30,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 1,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-13",
#         "weekday": "Saturday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 3,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 6,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 12,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 23,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 24,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-13",
#         "weekday": "Saturday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 4,
#                 "role": "Head"
#             },
#             {
#                 "id": 12,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 28,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 4,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-13",
#         "weekday": "Saturday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 3,
#                 "role": "Head"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 17,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 22,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 23,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 3,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-14",
#         "weekday": "Sunday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 4,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 5,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 7,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 8,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 18,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 30,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-14",
#         "weekday": "Sunday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 2,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 4,
#                 "role": "Head"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 28,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 4,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-14",
#         "weekday": "Sunday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 5,
#                 "role": "Head"
#             },
#             {
#                 "id": 8,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 10,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 5,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-15",
#         "weekday": "Monday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 3,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 18,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 19,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 25,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-15",
#         "weekday": "Monday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 2,
#                 "role": "Head"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 22,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 24,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 2,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-15",
#         "weekday": "Monday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 2,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 4,
#                 "role": "Head"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 23,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 27,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 4,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-16",
#         "weekday": "Tuesday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 3,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 7,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 8,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 9,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 16,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-16",
#         "weekday": "Tuesday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 5,
#                 "role": "Head"
#             },
#             {
#                 "id": 6,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 16,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 5,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-16",
#         "weekday": "Tuesday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 5,
#                 "role": "Head"
#             },
#             {
#                 "id": 6,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 18,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 22,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 25,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 5,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-17",
#         "weekday": "Wednesday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 3,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 8,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 19,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-17",
#         "weekday": "Wednesday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 4,
#                 "role": "Head"
#             },
#             {
#                 "id": 7,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 23,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 24,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 4,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-17",
#         "weekday": "Wednesday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Head"
#             },
#             {
#                 "id": 8,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 12,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 16,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 1,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-18",
#         "weekday": "Thursday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 3,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 28,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-18",
#         "weekday": "Thursday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 3,
#                 "role": "Head"
#             },
#             {
#                 "id": 10,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 19,
#                 "role": "Nurse"
#             },
#             {
# ...
#             },
#             {
#                 "id": 4,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 12,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 2,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-26",
#         "weekday": "Friday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Head"
#             },
#             {
#                 "id": 5,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 6,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 9,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 10,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 25,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 28,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 1,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-26",
#         "weekday": "Friday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 3,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 5,
#                 "role": "Head"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 27,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 30,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 5,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-26",
#         "weekday": "Friday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 3,
#                 "role": "Head"
#             },
#             {
#                 "id": 9,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 10,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 19,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 22,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 3,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-27",
#         "weekday": "Saturday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 2,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 25,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 27,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 30,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-27",
#         "weekday": "Saturday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 2,
#                 "role": "Head"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 18,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 24,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 27,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 2,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-27",
#         "weekday": "Saturday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Head"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 16,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 23,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 1,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-28",
#         "weekday": "Sunday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 7,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 10,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 19,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-28",
#         "weekday": "Sunday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 2,
#                 "role": "Head"
#             },
#             {
#                 "id": 12,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 17,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 18,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 24,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 2,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-28",
#         "weekday": "Sunday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 4,
#                 "role": "Head"
#             },
#             {
#                 "id": 6,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 15,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 28,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 30,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 4,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-29",
#         "weekday": "Monday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 5,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 18,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 24,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 27,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-29",
#         "weekday": "Monday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 3,
#                 "role": "Head"
#             },
#             {
#                 "id": 7,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 14,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 19,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 27,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 3,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-29",
#         "weekday": "Monday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 5,
#                 "role": "Head"
#             },
#             {
#                 "id": 7,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 9,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 11,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 12,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 22,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 5,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-30",
#         "weekday": "Tuesday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 6,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 23,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 24,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-30",
#         "weekday": "Tuesday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 2,
#                 "role": "Head"
#             },
#             {
#                 "id": 13,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 23,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 25,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 29,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 30,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 2,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-30",
#         "weekday": "Tuesday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 1,
#                 "role": "Head"
#             },
#             {
#                 "id": 10,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 16,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 18,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 24,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 31,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 1,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-31",
#         "weekday": "Wednesday",
#         "shift": "day",
#         "nurses_assigned": [
#             {
#                 "id": 0,
#                 "role": "CNL"
#             },
#             {
#                 "id": 6,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 19,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 27,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": null,
#             "role": "None"
#         },
#         "cnl_nurse": {
#             "id": 0,
#             "role": "CNL"
#         }
#     },
#     {
#         "date": "2024-01-31",
#         "weekday": "Wednesday",
#         "shift": "evening",
#         "nurses_assigned": [
#             {
#                 "id": 2,
#                 "role": "Head"
#             },
#             {
#                 "id": 4,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 12,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 20,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 26,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 28,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 2,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     },
#     {
#         "date": "2024-01-31",
#         "weekday": "Wednesday",
#         "shift": "night",
#         "nurses_assigned": [
#             {
#                 "id": 5,
#                 "role": "Head"
#             },
#             {
#                 "id": 6,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 9,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 12,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 19,
#                 "role": "Nurse"
#             },
#             {
#                 "id": 21,
#                 "role": "Nurse"
#             }
#         ],
#         "head_nurse": {
#             "id": 5,
#             "role": "Head"
#         },
#         "cnl_nurse": {
#             "id": null,
#             "role": "None"
#         }
#     }
# ]

# %%
print("Status:", LpStatus[prob.status])
# Out:
# Status: Optimal
